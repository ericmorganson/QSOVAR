# %%
from astropy.io import fits
#fits_image_filename = astropy.io.fits.open('../C1_lc.fits')

with fits.open('../C1_lc.fits') as hdul:
    print(hdul[1].columns)
# Out:
# ColDefs(
#     name = 'COADD_OBJECT_ID'; format = 'J'
#     name = 'RA'; format = 'E'
#     name = 'DEC'; format = 'E'
#     name = 'MAGERR_AUTO_G'; format = 'E'
#     name = 'MAGERR_AUTO_R'; format = 'E'
#     name = 'MAGERR_AUTO_I'; format = 'E'
#     name = 'MAGERR_AUTO_Z'; format = 'E'
#     name = 'MAGERR_AUTO_Y'; format = 'E'
#     name = 'MAGERR_DETMODEL_G'; format = 'E'
#     name = 'MAGERR_DETMODEL_R'; format = 'E'
#     name = 'MAGERR_DETMODEL_I'; format = 'E'
#     name = 'MAGERR_DETMODEL_Z'; format = 'E'
#     name = 'MAGERR_DETMODEL_Y'; format = 'E'
#     name = 'MAG_AUTO_G'; format = 'E'
#     name = 'MAG_AUTO_R'; format = 'E'
#     name = 'MAG_AUTO_I'; format = 'E'
#     name = 'MAG_AUTO_Z'; format = 'E'
#     name = 'MAG_AUTO_Y'; format = 'E'
#     name = 'MAG_DETMODEL_G'; format = 'E'
#     name = 'MAG_DETMODEL_R'; format = 'E'
#     name = 'MAG_DETMODEL_I'; format = 'E'
#     name = 'MAG_DETMODEL_Z'; format = 'E'
#     name = 'MAG_DETMODEL_Y'; format = 'E'
#     name = 'SPREAD_MODEL_G'; format = 'E'
#     name = 'SPREAD_MODEL_R'; format = 'E'
#     name = 'SPREAD_MODEL_I'; format = 'E'
#     name = 'SPREAD_MODEL_Z'; format = 'E'
#     name = 'SPREAD_MODEL_Y'; format = 'E'
#     name = 'SPREADERR_MODEL_G'; format = 'E'
#     name = 'SPREADERR_MODEL_R'; format = 'E'
#     name = 'SPREADERR_MODEL_I'; format = 'E'
#     name = 'SPREADERR_MODEL_Z'; format = 'E'
#     name = 'SPREADERR_MODEL_Y'; format = 'E'
#     name = 'FLAGS_G'; format = 'E'
#     name = 'FLAGS_I'; format = 'E'
#     name = 'FLAGS_R'; format = 'E'
#     name = 'FLAGS_Y'; format = 'E'
#     name = 'FLAGS_Z'; format = 'E'
#     name = 'NOBS_G'; format = 'E'
#     name = 'MEAN_PSF_G'; format = 'E'
#     name = 'MEANERR_PSF_G'; format = 'E'
#     name = 'MEDIAN_PSF_G'; format = 'E'
#     name = 'STD_PSF_G'; format = 'E'
#     name = 'CHI2_PSF_G'; format = 'E'
#     name = 'MAD_PSF_G'; format = 'E'
#     name = 'ROMS_PSF_G'; format = 'E'
#     name = 'NXS_PSF_G'; format = 'E'
#     name = 'MXS_PSF_G'; format = 'E'
#     name = 'MEAN_AUTO_G'; format = 'E'
#     name = 'MEANERR_AUTO_G'; format = 'E'
#     name = 'MEDIAN_AUTO_G'; format = 'E'
#     name = 'STD_AUTO_G'; format = 'E'
#     name = 'CHI2_AUTO_G'; format = 'E'
#     name = 'MAD_AUTO_G'; format = 'E'
#     name = 'ROMS_AUTO_G'; format = 'E'
#     name = 'NXS_AUTO_G'; format = 'E'
#     name = 'MXS_AUTO_G'; format = 'E'
#     name = 'NOBS_R'; format = 'E'
#     name = 'MEAN_PSF_R'; format = 'E'
#     name = 'MEANERR_PSF_R'; format = 'E'
#     name = 'MEDIAN_PSF_R'; format = 'E'
#     name = 'STD_PSF_R'; format = 'E'
#     name = 'CHI2_PSF_R'; format = 'E'
#     name = 'MAD_PSF_R'; format = 'E'
#     name = 'ROMS_PSF_R'; format = 'E'
#     name = 'NXS_PSF_R'; format = 'E'
#     name = 'MXS_PSF_R'; format = 'E'
#     name = 'MEAN_AUTO_R'; format = 'E'
#     name = 'MEANERR_AUTO_R'; format = 'E'
#     name = 'MEDIAN_AUTO_R'; format = 'E'
#     name = 'STD_AUTO_R'; format = 'E'
#     name = 'CHI2_AUTO_R'; format = 'E'
#     name = 'MAD_AUTO_R'; format = 'E'
#     name = 'ROMS_AUTO_R'; format = 'E'
#     name = 'NXS_AUTO_R'; format = 'E'
#     name = 'MXS_AUTO_R'; format = 'E'
#     name = 'NOBS_I'; format = 'E'
#     name = 'MEAN_PSF_I'; format = 'E'
#     name = 'MEANERR_PSF_I'; format = 'E'
#     name = 'MEDIAN_PSF_I'; format = 'E'
#     name = 'STD_PSF_I'; format = 'E'
#     name = 'CHI2_PSF_I'; format = 'E'
#     name = 'MAD_PSF_I'; format = 'E'
#     name = 'ROMS_PSF_I'; format = 'E'
#     name = 'NXS_PSF_I'; format = 'E'
#     name = 'MXS_PSF_I'; format = 'E'
#     name = 'MEAN_AUTO_I'; format = 'E'
#     name = 'MEANERR_AUTO_I'; format = 'E'
#     name = 'MEDIAN_AUTO_I'; format = 'E'
#     name = 'STD_AUTO_I'; format = 'E'
#     name = 'CHI2_AUTO_I'; format = 'E'
#     name = 'MAD_AUTO_I'; format = 'E'
#     name = 'ROMS_AUTO_I'; format = 'E'
#     name = 'NXS_AUTO_I'; format = 'E'
#     name = 'MXS_AUTO_I'; format = 'E'
#     name = 'NOBS_Z'; format = 'E'
#     name = 'MEAN_PSF_Z'; format = 'E'
#     name = 'MEANERR_PSF_Z'; format = 'E'
#     name = 'MEDIAN_PSF_Z'; format = 'E'
#     name = 'STD_PSF_Z'; format = 'E'
#     name = 'CHI2_PSF_Z'; format = 'E'
#     name = 'MAD_PSF_Z'; format = 'E'
#     name = 'ROMS_PSF_Z'; format = 'E'
#     name = 'NXS_PSF_Z'; format = 'E'
#     name = 'MXS_PSF_Z'; format = 'E'
#     name = 'MEAN_AUTO_Z'; format = 'E'
#     name = 'MEANERR_AUTO_Z'; format = 'E'
#     name = 'MEDIAN_AUTO_Z'; format = 'E'
#     name = 'STD_AUTO_Z'; format = 'E'
#     name = 'CHI2_AUTO_Z'; format = 'E'
#     name = 'MAD_AUTO_Z'; format = 'E'
#     name = 'ROMS_AUTO_Z'; format = 'E'
#     name = 'NXS_AUTO_Z'; format = 'E'
#     name = 'MXS_AUTO_Z'; format = 'E'
#     name = 'NOBS_G_Y1'; format = 'E'
#     name = 'MEAN_PSF_G_Y1'; format = 'E'
#     name = 'MEANERR_PSF_G_Y1'; format = 'E'
#     name = 'MEDIAN_PSF_G_Y1'; format = 'E'
#     name = 'STD_PSF_G_Y1'; format = 'E'
#     name = 'CHI2_PSF_G_Y1'; format = 'E'
#     name = 'MAD_PSF_G_Y1'; format = 'E'
#     name = 'ROMS_PSF_G_Y1'; format = 'E'
#     name = 'NXS_PSF_G_Y1'; format = 'E'
#     name = 'MXS_PSF_G_Y1'; format = 'E'
#     name = 'MEAN_AUTO_G_Y1'; format = 'E'
#     name = 'MEANERR_AUTO_G_Y1'; format = 'E'
#     name = 'MEDIAN_AUTO_G_Y1'; format = 'E'
#     name = 'STD_AUTO_G_Y1'; format = 'E'
#     name = 'CHI2_AUTO_G_Y1'; format = 'E'
#     name = 'MAD_AUTO_G_Y1'; format = 'E'
#     name = 'ROMS_AUTO_G_Y1'; format = 'E'
#     name = 'NXS_AUTO_G_Y1'; format = 'E'
#     name = 'MXS_AUTO_G_Y1'; format = 'E'
#     name = 'NOBS_R_Y1'; format = 'E'
#     name = 'MEAN_PSF_R_Y1'; format = 'E'
#     name = 'MEANERR_PSF_R_Y1'; format = 'E'
#     name = 'MEDIAN_PSF_R_Y1'; format = 'E'
#     name = 'STD_PSF_R_Y1'; format = 'E'
#     name = 'CHI2_PSF_R_Y1'; format = 'E'
#     name = 'MAD_PSF_R_Y1'; format = 'E'
#     name = 'ROMS_PSF_R_Y1'; format = 'E'
#     name = 'NXS_PSF_R_Y1'; format = 'E'
#     name = 'MXS_PSF_R_Y1'; format = 'E'
#     name = 'MEAN_AUTO_R_Y1'; format = 'E'
#     name = 'MEANERR_AUTO_R_Y1'; format = 'E'
#     name = 'MEDIAN_AUTO_R_Y1'; format = 'E'
#     name = 'STD_AUTO_R_Y1'; format = 'E'
#     name = 'CHI2_AUTO_R_Y1'; format = 'E'
#     name = 'MAD_AUTO_R_Y1'; format = 'E'
#     name = 'ROMS_AUTO_R_Y1'; format = 'E'
#     name = 'NXS_AUTO_R_Y1'; format = 'E'
#     name = 'MXS_AUTO_R_Y1'; format = 'E'
#     name = 'NOBS_I_Y1'; format = 'E'
#     name = 'MEAN_PSF_I_Y1'; format = 'E'
#     name = 'MEANERR_PSF_I_Y1'; format = 'E'
#     name = 'MEDIAN_PSF_I_Y1'; format = 'E'
#     name = 'STD_PSF_I_Y1'; format = 'E'
#     name = 'CHI2_PSF_I_Y1'; format = 'E'
#     name = 'MAD_PSF_I_Y1'; format = 'E'
#     name = 'ROMS_PSF_I_Y1'; format = 'E'
#     name = 'NXS_PSF_I_Y1'; format = 'E'
#     name = 'MXS_PSF_I_Y1'; format = 'E'
#     name = 'MEAN_AUTO_I_Y1'; format = 'E'
#     name = 'MEANERR_AUTO_I_Y1'; format = 'E'
#     name = 'MEDIAN_AUTO_I_Y1'; format = 'E'
#     name = 'STD_AUTO_I_Y1'; format = 'E'
#     name = 'CHI2_AUTO_I_Y1'; format = 'E'
#     name = 'MAD_AUTO_I_Y1'; format = 'E'
#     name = 'ROMS_AUTO_I_Y1'; format = 'E'
#     name = 'NXS_AUTO_I_Y1'; format = 'E'
#     name = 'MXS_AUTO_I_Y1'; format = 'E'
#     name = 'NOBS_Z_Y1'; format = 'E'
#     name = 'MEAN_PSF_Z_Y1'; format = 'E'
#     name = 'MEANERR_PSF_Z_Y1'; format = 'E'
#     name = 'MEDIAN_PSF_Z_Y1'; format = 'E'
#     name = 'STD_PSF_Z_Y1'; format = 'E'
#     name = 'CHI2_PSF_Z_Y1'; format = 'E'
#     name = 'MAD_PSF_Z_Y1'; format = 'E'
#     name = 'ROMS_PSF_Z_Y1'; format = 'E'
#     name = 'NXS_PSF_Z_Y1'; format = 'E'
#     name = 'MXS_PSF_Z_Y1'; format = 'E'
#     name = 'MEAN_AUTO_Z_Y1'; format = 'E'
#     name = 'MEANERR_AUTO_Z_Y1'; format = 'E'
#     name = 'MEDIAN_AUTO_Z_Y1'; format = 'E'
#     name = 'STD_AUTO_Z_Y1'; format = 'E'
#     name = 'CHI2_AUTO_Z_Y1'; format = 'E'
#     name = 'MAD_AUTO_Z_Y1'; format = 'E'
#     name = 'ROMS_AUTO_Z_Y1'; format = 'E'
#     name = 'NXS_AUTO_Z_Y1'; format = 'E'
#     name = 'MXS_AUTO_Z_Y1'; format = 'E'
#     name = 'NOBS_G_Y2'; format = 'E'
#     name = 'MEAN_PSF_G_Y2'; format = 'E'
#     name = 'MEANERR_PSF_G_Y2'; format = 'E'
#     name = 'MEDIAN_PSF_G_Y2'; format = 'E'
#     name = 'STD_PSF_G_Y2'; format = 'E'
#     name = 'CHI2_PSF_G_Y2'; format = 'E'
#     name = 'MAD_PSF_G_Y2'; format = 'E'
#     name = 'ROMS_PSF_G_Y2'; format = 'E'
#     name = 'NXS_PSF_G_Y2'; format = 'E'
#     name = 'MXS_PSF_G_Y2'; format = 'E'
#     name = 'MEAN_AUTO_G_Y2'; format = 'E'
#     name = 'MEANERR_AUTO_G_Y2'; format = 'E'
#     name = 'MEDIAN_AUTO_G_Y2'; format = 'E'
#     name = 'STD_AUTO_G_Y2'; format = 'E'
#     name = 'CHI2_AUTO_G_Y2'; format = 'E'
#     name = 'MAD_AUTO_G_Y2'; format = 'E'
#     name = 'ROMS_AUTO_G_Y2'; format = 'E'
#     name = 'NXS_AUTO_G_Y2'; format = 'E'
#     name = 'MXS_AUTO_G_Y2'; format = 'E'
#     name = 'NOBS_R_Y2'; format = 'E'
#     name = 'MEAN_PSF_R_Y2'; format = 'E'
#     name = 'MEANERR_PSF_R_Y2'; format = 'E'
#     name = 'MEDIAN_PSF_R_Y2'; format = 'E'
#     name = 'STD_PSF_R_Y2'; format = 'E'
#     name = 'CHI2_PSF_R_Y2'; format = 'E'
#     name = 'MAD_PSF_R_Y2'; format = 'E'
#     name = 'ROMS_PSF_R_Y2'; format = 'E'
#     name = 'NXS_PSF_R_Y2'; format = 'E'
#     name = 'MXS_PSF_R_Y2'; format = 'E'
#     name = 'MEAN_AUTO_R_Y2'; format = 'E'
#     name = 'MEANERR_AUTO_R_Y2'; format = 'E'
#     name = 'MEDIAN_AUTO_R_Y2'; format = 'E'
#     name = 'STD_AUTO_R_Y2'; format = 'E'
#     name = 'CHI2_AUTO_R_Y2'; format = 'E'
#     name = 'MAD_AUTO_R_Y2'; format = 'E'
#     name = 'ROMS_AUTO_R_Y2'; format = 'E'
#     name = 'NXS_AUTO_R_Y2'; format = 'E'
#     name = 'MXS_AUTO_R_Y2'; format = 'E'
#     name = 'NOBS_I_Y2'; format = 'E'
#     name = 'MEAN_PSF_I_Y2'; format = 'E'
#     name = 'MEANERR_PSF_I_Y2'; format = 'E'
#     name = 'MEDIAN_PSF_I_Y2'; format = 'E'
#     name = 'STD_PSF_I_Y2'; format = 'E'
#     name = 'CHI2_PSF_I_Y2'; format = 'E'
#     name = 'MAD_PSF_I_Y2'; format = 'E'
#     name = 'ROMS_PSF_I_Y2'; format = 'E'
#     name = 'NXS_PSF_I_Y2'; format = 'E'
#     name = 'MXS_PSF_I_Y2'; format = 'E'
#     name = 'MEAN_AUTO_I_Y2'; format = 'E'
#     name = 'MEANERR_AUTO_I_Y2'; format = 'E'
#     name = 'MEDIAN_AUTO_I_Y2'; format = 'E'
#     name = 'STD_AUTO_I_Y2'; format = 'E'
#     name = 'CHI2_AUTO_I_Y2'; format = 'E'
#     name = 'MAD_AUTO_I_Y2'; format = 'E'
#     name = 'ROMS_AUTO_I_Y2'; format = 'E'
#     name = 'NXS_AUTO_I_Y2'; format = 'E'
#     name = 'MXS_AUTO_I_Y2'; format = 'E'
#     name = 'NOBS_Z_Y2'; format = 'E'
#     name = 'MEAN_PSF_Z_Y2'; format = 'E'
#     name = 'MEANERR_PSF_Z_Y2'; format = 'E'
#     name = 'MEDIAN_PSF_Z_Y2'; format = 'E'
#     name = 'STD_PSF_Z_Y2'; format = 'E'
#     name = 'CHI2_PSF_Z_Y2'; format = 'E'
#     name = 'MAD_PSF_Z_Y2'; format = 'E'
#     name = 'ROMS_PSF_Z_Y2'; format = 'E'
#     name = 'NXS_PSF_Z_Y2'; format = 'E'
#     name = 'MXS_PSF_Z_Y2'; format = 'E'
#     name = 'MEAN_AUTO_Z_Y2'; format = 'E'
#     name = 'MEANERR_AUTO_Z_Y2'; format = 'E'
#     name = 'MEDIAN_AUTO_Z_Y2'; format = 'E'
#     name = 'STD_AUTO_Z_Y2'; format = 'E'
#     name = 'CHI2_AUTO_Z_Y2'; format = 'E'
#     name = 'MAD_AUTO_Z_Y2'; format = 'E'
#     name = 'ROMS_AUTO_Z_Y2'; format = 'E'
#     name = 'NXS_AUTO_Z_Y2'; format = 'E'
#     name = 'MXS_AUTO_Z_Y2'; format = 'E'
#     name = 'NOBS_G_Y3'; format = 'E'
#     name = 'MEAN_PSF_G_Y3'; format = 'E'
#     name = 'MEANERR_PSF_G_Y3'; format = 'E'
#     name = 'MEDIAN_PSF_G_Y3'; format = 'E'
#     name = 'STD_PSF_G_Y3'; format = 'E'
#     name = 'CHI2_PSF_G_Y3'; format = 'E'
#     name = 'MAD_PSF_G_Y3'; format = 'E'
#     name = 'ROMS_PSF_G_Y3'; format = 'E'
#     name = 'NXS_PSF_G_Y3'; format = 'E'
#     name = 'MXS_PSF_G_Y3'; format = 'E'
#     name = 'MEAN_AUTO_G_Y3'; format = 'E'
#     name = 'MEANERR_AUTO_G_Y3'; format = 'E'
#     name = 'MEDIAN_AUTO_G_Y3'; format = 'E'
#     name = 'STD_AUTO_G_Y3'; format = 'E'
#     name = 'CHI2_AUTO_G_Y3'; format = 'E'
#     name = 'MAD_AUTO_G_Y3'; format = 'E'
#     name = 'ROMS_AUTO_G_Y3'; format = 'E'
#     name = 'NXS_AUTO_G_Y3'; format = 'E'
#     name = 'MXS_AUTO_G_Y3'; format = 'E'
#     name = 'NOBS_R_Y3'; format = 'E'
#     name = 'MEAN_PSF_R_Y3'; format = 'E'
#     name = 'MEANERR_PSF_R_Y3'; format = 'E'
#     name = 'MEDIAN_PSF_R_Y3'; format = 'E'
#     name = 'STD_PSF_R_Y3'; format = 'E'
#     name = 'CHI2_PSF_R_Y3'; format = 'E'
#     name = 'MAD_PSF_R_Y3'; format = 'E'
#     name = 'ROMS_PSF_R_Y3'; format = 'E'
#     name = 'NXS_PSF_R_Y3'; format = 'E'
#     name = 'MXS_PSF_R_Y3'; format = 'E'
#     name = 'MEAN_AUTO_R_Y3'; format = 'E'
#     name = 'MEANERR_AUTO_R_Y3'; format = 'E'
#     name = 'MEDIAN_AUTO_R_Y3'; format = 'E'
#     name = 'STD_AUTO_R_Y3'; format = 'E'
#     name = 'CHI2_AUTO_R_Y3'; format = 'E'
#     name = 'MAD_AUTO_R_Y3'; format = 'E'
#     name = 'ROMS_AUTO_R_Y3'; format = 'E'
#     name = 'NXS_AUTO_R_Y3'; format = 'E'
#     name = 'MXS_AUTO_R_Y3'; format = 'E'
#     name = 'NOBS_I_Y3'; format = 'E'
#     name = 'MEAN_PSF_I_Y3'; format = 'E'
#     name = 'MEANERR_PSF_I_Y3'; format = 'E'
#     name = 'MEDIAN_PSF_I_Y3'; format = 'E'
#     name = 'STD_PSF_I_Y3'; format = 'E'
#     name = 'CHI2_PSF_I_Y3'; format = 'E'
#     name = 'MAD_PSF_I_Y3'; format = 'E'
#     name = 'ROMS_PSF_I_Y3'; format = 'E'
#     name = 'NXS_PSF_I_Y3'; format = 'E'
#     name = 'MXS_PSF_I_Y3'; format = 'E'
#     name = 'MEAN_AUTO_I_Y3'; format = 'E'
#     name = 'MEANERR_AUTO_I_Y3'; format = 'E'
#     name = 'MEDIAN_AUTO_I_Y3'; format = 'E'
#     name = 'STD_AUTO_I_Y3'; format = 'E'
#     name = 'CHI2_AUTO_I_Y3'; format = 'E'
#     name = 'MAD_AUTO_I_Y3'; format = 'E'
#     name = 'ROMS_AUTO_I_Y3'; format = 'E'
#     name = 'NXS_AUTO_I_Y3'; format = 'E'
#     name = 'MXS_AUTO_I_Y3'; format = 'E'
#     name = 'NOBS_Z_Y3'; format = 'E'
#     name = 'MEAN_PSF_Z_Y3'; format = 'E'
#     name = 'MEANERR_PSF_Z_Y3'; format = 'E'
#     name = 'MEDIAN_PSF_Z_Y3'; format = 'E'
#     name = 'STD_PSF_Z_Y3'; format = 'E'
#     name = 'CHI2_PSF_Z_Y3'; format = 'E'
#     name = 'MAD_PSF_Z_Y3'; format = 'E'
#     name = 'ROMS_PSF_Z_Y3'; format = 'E'
#     name = 'NXS_PSF_Z_Y3'; format = 'E'
#     name = 'MXS_PSF_Z_Y3'; format = 'E'
#     name = 'MEAN_AUTO_Z_Y3'; format = 'E'
#     name = 'MEANERR_AUTO_Z_Y3'; format = 'E'
#     name = 'MEDIAN_AUTO_Z_Y3'; format = 'E'
#     name = 'STD_AUTO_Z_Y3'; format = 'E'
#     name = 'CHI2_AUTO_Z_Y3'; format = 'E'
#     name = 'MAD_AUTO_Z_Y3'; format = 'E'
#     name = 'ROMS_AUTO_Z_Y3'; format = 'E'
#     name = 'NXS_AUTO_Z_Y3'; format = 'E'
#     name = 'MXS_AUTO_Z_Y3'; format = 'E'
#     name = 'LC_FLUX_PSF_G'; format = '75E'
#     name = 'LC_FLUXERR_PSF_G'; format = '75E'
#     name = 'LC_FLUX_AUTO_G'; format = '75E'
#     name = 'LC_FLUXERR_AUTO_G'; format = '75E'
#     name = 'LC_MJD_G'; format = '75E'
#     name = 'LC_FLUX_PSF_R'; format = '76E'
#     name = 'LC_FLUXERR_PSF_R'; format = '76E'
#     name = 'LC_FLUX_AUTO_R'; format = '76E'
#     name = 'LC_FLUXERR_AUTO_R'; format = '76E'
#     name = 'LC_MJD_R'; format = '76E'
#     name = 'LC_FLUX_PSF_I'; format = '84E'
#     name = 'LC_FLUXERR_PSF_I'; format = '84E'
#     name = 'LC_FLUX_AUTO_I'; format = '84E'
#     name = 'LC_FLUXERR_AUTO_I'; format = '84E'
#     name = 'LC_MJD_I'; format = '84E'
#     name = 'LC_FLUX_PSF_Z'; format = '167E'
#     name = 'LC_FLUXERR_PSF_Z'; format = '167E'
#     name = 'LC_FLUX_AUTO_Z'; format = '167E'
#     name = 'LC_FLUXERR_AUTO_Z'; format = '167E'
#     name = 'LC_MJD_Z'; format = '167E'
# )

# %%
# %matplotlib inline 
import astropy.io.fits as pyfit
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
from scipy import stats

FITS = pyfit.open(r'/home/sam/Documents/Morganson_research/C1_lc.fits')

def get_vals(file, ROW):
        color_dict = {"g":1, "r":2, "i":3, "z":4}
        lc_median = {}
        time = np.array([])
        flux_norm = np.array([])
        flux_err_norm = np.array([])
        array_org = np.array([])
        fig = plt.figure(figsize=(15, 7))
        ax5 = fig.add_subplot(111)
        color_plt=iter(cm.rainbow(np.linspace(0,1,5)))
        for color in "griz":
            FITS = pyfit.open(file)

            #Obtain flux, err, and time arrays
            try:
                lc_flux = FITS[1].data['LC_FLUX_PSF_'+color][ROW]
            except IndexError:
                print('Error')
                exit()

            lc_median[color] = FITS[1].data['MEDIAN_PSF_'+color][ROW]
            lc_flux_err = FITS[1].data['LC_FLUXERR_PSF_'+color][ROW]
            lc_time = FITS[1].data['LC_MJD_'+color][ROW]
            time = np.append(time, lc_time[lc_time != 0.]) #remove the zeros

            limit = len(lc_time[lc_time!=0])
            array_org = np.append(array_org, color_dict[color]*np.ones(limit))
            lc_flux = lc_flux[:limit]
            lc_flux_err = lc_flux_err[:limit]
            col=next(color_plt)

            ax5.scatter(lc_time[lc_time!=0], (lc_flux[0:limit] - lc_median[color])/lc_median[color],  
                        label=color, c=np.array([col]))
            
            
            flux_norm = np.append(flux_norm, (lc_flux - lc_median[color])/lc_median[color])
            flux_err_norm = np.append(flux_err_norm, lc_flux_err/lc_median[color])
            
        ax5.legend()
        ax5.set_title("Pre-correction light curve")
        plt.show()
        lc_time, lc_flux_norm, lc_flux_err_norm, lc_array_org = map(list, zip(*sorted(zip(time, flux_norm,
                                                                                          flux_err_norm, array_org))))
        print(stats.describe(lc_flux_err_norm))
        return lc_flux_norm, lc_flux_err_norm, lc_time, lc_median, lc_array_org, FITS

# %%
flux, err, time, mu, color_sort,  FITS = get_vals(r'/home/sam/Documents/Morganson_research/C1_lc.fits', 0)
# Out:
# DescribeResult(nobs=122, minmax=(0.035337626934051514, 0.2197740226984024), mean=0.09785545846355743, variance=0.001291290402017321, skewness=0.5843887775456735, kurtosis=0.09575243370903586)

# %%
flux, err, time, mu, color_sort,  FITS = get_vals(r'/home/sam/Documents/Morganson_research/C1_lc.fits', 8)
# Out:
# DescribeResult(nobs=101, minmax=(0.039990395307540894, 0.19630111753940582), mean=0.10197500180047338, variance=0.0013086351647951188, skewness=0.25680675995936153, kurtosis=-0.5342080004270042)

# %%
flux, err, time, mu, color_sort,  FITS = get_vals(r'/home/sam/Documents/Morganson_research/C1_lc.fits', 18)
# Out:
# DescribeResult(nobs=155, minmax=(0.043337151408195496, 0.22810044884681702), mean=0.09995106223129457, variance=0.0010062294378338228, skewness=0.9164542974535418, kurtosis=1.4754231888737754)

# %%
flux, err, time, mu, color_sort,  FITS = get_vals(r'/home/sam/Documents/Morganson_research/C1_lc.fits', 2)
# Out:
# DescribeResult(nobs=155, minmax=(0.014631563797593117, 0.12878021597862244), mean=0.03435839959570477, variance=0.0006021703797683605, skewness=2.174749140988064, kurtosis=4.044706054666955)

# %%
flux, err, time, mu, color_sort,  FITS = get_vals(r'/home/sam/Documents/Morganson_research/C1_lc.fits', 10)
# Out:
# DescribeResult(nobs=156, minmax=(0.047204066067934036, 0.21356014907360077), mean=0.09238632646604227, variance=0.0006592603292710618, skewness=1.1329353390489405, kurtosis=2.715746001326453)

# %%
flux, err, time, mu, color_sort,  FITS = get_vals(r'/home/sam/Documents/Morganson_research/C1_lc.fits', 20)
# Out:
# DescribeResult(nobs=174, minmax=(0.01613154634833336, 0.1693783849477768), mean=0.042824436589304744, variance=0.0009233883996666613, skewness=2.1480483498423615, kurtosis=4.455457152039525)
